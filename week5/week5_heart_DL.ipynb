# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
df = pd.read_csv("/Users/yenalee/Desktop/workplace/AI_2025-1/week5/heart.csv") # 로컬(MAC)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
x = df.drop('target', axis=1)
y = df['target']

# %%
Y = pd.get_dummies(y).values

# %%
Y
# Out:
# array([[False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False]])

# %%
x = x.values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,Y,test_size=0.2,random_state=0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((242, 13), (61, 13), (242, 2), (61, 2))

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(25, input_shape=(13,),activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(2, activation='sigmoid'))
model.compile(Adam(learning_rate=0.01),'binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 20)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 2)              │            22 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 518 (2.02 KB)
#  Trainable params: 518 (2.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history=model.fit(x=x_train, y=y_train, epochs=30, batch_size=32,validation_split=0.1) # validation_data= (X_test,y_test)
y_pred = model.predict(x_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4680 - loss: 0.7600 - val_accuracy: 0.6000 - val_loss: 0.6928
# Epoch 2/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5296 - loss: 0.6929 - val_accuracy: 0.4000 - val_loss: 0.6971
# Epoch 3/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5442 - loss: 0.6913 - val_accuracy: 0.4000 - val_loss: 0.7006
# Epoch 4/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5498 - loss: 0.6901 - val_accuracy: 0.4000 - val_loss: 0.7042
# Epoch 5/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5587 - loss: 0.6884 - val_accuracy: 0.4000 - val_loss: 0.7079
# Epoch 6/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5873 - loss: 0.6841 - val_accuracy: 0.4000 - val_loss: 0.7113
# Epoch 7/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5683 - loss: 0.6856 - val_accuracy: 0.4000 - val_loss: 0.7136
# Epoch 8/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5964 - loss: 0.6805 - val_accuracy: 0.4000 - val_loss: 0.7160
# Epoch 9/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5570 - loss: 0.6869 - val_accuracy: 0.4000 - val_loss: 0.7170
# Epoch 10/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6048 - loss: 0.6777 - val_accuracy: 0.4000 - val_loss: 0.7186
# Epoch 11/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5502 - loss: 0.6881 - val_accuracy: 0.4000 - val_loss: 0.7190
# Epoch 12/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5695 - loss: 0.6842 - val_accuracy: 0.4000 - val_loss: 0.7193
# Epoch 13/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5508 - loss: 0.6880 - val_accuracy: 0.4000 - val_loss: 0.7199
# Epoch 14/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5988 - loss: 0.6779 - val_accuracy: 0.4000 - val_loss: 0.7213
# Epoch 15/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5646 - loss: 0.6850 - val_accuracy: 0.4000 - val_loss: 0.7207
# Epoch 16/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5424 - loss: 0.6898 - val_accuracy: 0.4000 - val_loss: 0.7209
# Epoch 17/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5477 - loss: 0.6887 - val_accuracy: 0.4000 - val_loss: 0.7215
# Epoch 18/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5835 - loss: 0.6808 - val_accuracy: 0.4000 - val_loss: 0.7225
# Epoch 19/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6449 - loss: 0.6667 - val_accuracy: 0.4000 - val_loss: 0.7236
# Epoch 20/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5896 - loss: 0.6789 - val_accuracy: 0.4000 - val_loss: 0.7225
# Epoch 21/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5789 - loss: 0.6817 - val_accuracy: 0.4000 - val_loss: 0.7224
# Epoch 22/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5425 - loss: 0.6900 - val_accuracy: 0.4000 - val_loss: 0.7211
# Epoch 23/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5542 - loss: 0.6873 - val_accuracy: 0.4000 - val_loss: 0.7203
# Epoch 24/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5694 - loss: 0.6840 - val_accuracy: 0.4000 - val_loss: 0.7209
# Epoch 25/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5726 - loss: 0.6833 - val_accuracy: 0.4000 - val_loss: 0.7215
# Epoch 26/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5624 - loss: 0.6855 - val_accuracy: 0.4000 - val_loss: 0.7217
# Epoch 27/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5338 - loss: 0.6918 - val_accuracy: 0.4000 - val_loss: 0.7214
# Epoch 28/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5587 - loss: 0.6863 - val_accuracy: 0.4000 - val_loss: 0.7220
# Epoch 29/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5804 - loss: 0.6815 - val_accuracy: 0.4000 - val_loss: 0.7228
# Epoch 30/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5734 - loss: 0.6829 - val_accuracy: 0.4000 - val_loss: 0.7238
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.76        27
#            1       0.82      0.79      0.81        34
#
#     accuracy                           0.79        61
#    macro avg       0.78      0.79      0.78        61
# weighted avg       0.79      0.79      0.79        61
#
# [[21  6]
#  [ 7 27]]
